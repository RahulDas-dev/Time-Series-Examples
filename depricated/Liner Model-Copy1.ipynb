# %% [markdown]
# ### Library Import

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import sktime

from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.compose import (
    ForecastingPipeline,
    make_reduction,
    TransformedTargetForecaster,
)
from sktime.transformations.series.adapt import TabularToSeriesAdaptor
from sktime.forecasting.model_selection import (
    ExpandingWindowSplitter,
    SlidingWindowSplitter,
    temporal_train_test_split,
)
from sktime.forecasting.model_evaluation import evaluate
from sktime.performance_metrics.forecasting import (
    MeanSquaredError,
    MeanAbsoluteError,
    MeanAbsolutePercentageError,
)

from sktime.transformations.compose import Id

from sktime.utils import plotting


from sktime.utils import plotting


from sklearn.linear_model import (
    LinearRegression,
    ElasticNetCV,
    MultiTaskElasticNetCV,
    MultiTaskElasticNet,
    RidgeCV,
    LassoCV,
    HuberRegressor,
)
from sklearn.multioutput import MultiOutputRegressor

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from lerner.sanity import *

# %%
np.random.seed(80)

plt.style.use("seaborn-v0_8-darkgrid")

sktime.__version__
# Out:
# '0.18.0'

# %%
csv_path = "./data/jena_climate_2009_2016.csv"
columns = [
    "Date Time",
    "p (mbar)",
    "T (degC)",
    "Tpot (K)",
    "Tdew (degC)",
    "rh (%)",
    "VPmax (mbar)",
    "VPdef (mbar)",
    "sh (g/kg)",
    "H2OC (mmol/mol)",
]

dataframe = (
    load_data(csv_path)
    .pipe(select_column, columns)
    .pipe(create_index, "Date Time", format="%d.%m.%Y %H:%M:%S")
    .pipe(resample_Data, "D")
    .pipe(replace_null)
    # .pipe(drop_indicies)
)

print(f"Shape {dataframe.shape}")
dataframe.head()
# Out:
# load_data: DF Shape (420551, 15)
# select_column: DF Shape (420551, 10)
# format_datetime: DF Shape (420551, 9)
# resample_Data: DF Shape (2923, 9)
# replace_null: DF Shape (2923, 9)
# Shape (2923, 9)
#             p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# Index
# 2009-01-01    999.67     -4.58    268.61        -5.62    92.4          4.34
# 2009-01-02   1002.35     -4.59    268.39        -6.03    89.6          4.34
# 2009-01-03    993.05     -1.90    271.80        -6.46    70.8          5.31
# 2009-01-04    985.12     -1.50    272.83        -2.48    93.0          5.47
# 2009-01-05    997.51    -12.54    260.81       -15.01    81.6          2.32
#
#             VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)
# Index
# 2009-01-01          0.33       2.50             4.02
# 2009-01-02          0.45       2.42             3.88
# 2009-01-03          1.55       2.36             3.79
# 2009-01-04          0.38       3.22             5.16
# 2009-01-05          0.43       1.18             1.90

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2923 entries, 2009-01-01 to 2017-01-01
# Freq: D
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   p (mbar)         2923 non-null   float64
#  1   T (degC)         2923 non-null   float64
#  2   Tpot (K)         2923 non-null   float64
#  3   Tdew (degC)      2923 non-null   float64
#  4   rh (%)           2923 non-null   float64
#  5   VPmax (mbar)     2923 non-null   float64
#  6   VPdef (mbar)     2923 non-null   float64
#  7   sh (g/kg)        2923 non-null   float64
#  8   H2OC (mmol/mol)  2923 non-null   float64
# dtypes: float64(9)
# memory usage: 228.4 KB

# %% [markdown]
# ### Forcasting all Columns single step [ Ignore]

# %%
train_y, test_y = temporal_train_test_split(dataframe, test_size=24)

print(train_y.shape, test_y.shape)

target_column = ["H2OC (mmol/mol)"]
feat_column = [
    "p (mbar)",
    "T (degC)",
    "Tpot (K)",
    "Tdew (degC)",
    "rh (%)",
    "VPmax (mbar)",
    "VPdef (mbar)",
]

regressor = LinearRegression(fit_intercept=False)
regressor_e = ElasticNetCV(n_alphas=30, fit_intercept=False, cv=10)

regressor_r = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1, 10], cv=10, fit_intercept=False)

forecaster = make_reduction(
    regressor,
    # transformers=StandardScaler(),
    window_length=15,
    strategy="recursive",
)
ouput_seq_len = 24
fhzon = np.arange(ouput_seq_len) + 1

forecaster.fit(train_y)
# Out:
# (2899, 9) (24, 9)
# RecursiveTabularRegressionForecaster(estimator=LinearRegression(fit_intercept=False),
#                                      window_length=15)

# %%
dir(forecaster)
forecaster.forecasters_
h = forecaster.forecasters_["H2OC (mmol/mol)"].iloc(0)[0]
dir(h)
h.estimator_.coef_
# Out:
# array([ 0.05814815,  0.00340837,  0.00151339,  0.02701349,  0.01271704,
#         0.01745461, -0.00946742,  0.06191209, -0.01557919,  0.05958567,
#         0.02718781,  0.00676609,  0.03870583, -0.01254372,  0.71820877])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X, y)
reg.score(X, y)

reg.coef_
# Out:
# array([1., 2.])

# %% [markdown]
# ### Test Train Split For Singel Columns Multistep + Multivariate Forcasting

# %%
target_column = ["H2OC (mmol/mol)"]
feat_column = [
    "p (mbar)",
    "T (degC)",
    "Tpot (K)",
    "Tdew (degC)",
    "rh (%)",
    "VPmax (mbar)",
    "VPdef (mbar)",
]
input_seq_len = 30
ouput_seq_len = 24

y_train, y_test, x_train, x_test = temporal_train_test_split(
    dataframe[target_column], dataframe[feat_column], test_size=ouput_seq_len
)

# x_train = (x_train - x_train.mean())/x_train.std()

# x_test = (x_test - x_test.mean())/x_test.std()

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (2899, 7) (2899, 1) (24, 7) (24, 1)

# %%
x_train.head()
# Out:
#             p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# Index
# 2009-01-01    999.67     -4.58    268.61        -5.62    92.4          4.34
# 2009-01-02   1002.35     -4.59    268.39        -6.03    89.6          4.34
# 2009-01-03    993.05     -1.90    271.80        -6.46    70.8          5.31
# 2009-01-04    985.12     -1.50    272.83        -2.48    93.0          5.47
# 2009-01-05    997.51    -12.54    260.81       -15.01    81.6          2.32
#
#             VPdef (mbar)
# Index
# 2009-01-01          0.33
# 2009-01-02          0.45
# 2009-01-03          1.55
# 2009-01-04          0.38
# 2009-01-05          0.43

# %% [markdown]
# ### Model Prepattion and Training

# %%
fhzon = np.arange(ouput_seq_len) + 1

forecaster_pipe = TransformedTargetForecaster(
    [
        ("trnsformer", TabularToSeriesAdaptor(StandardScaler())),
        (
            "forecaster",
            make_reduction(
                LinearRegression(), window_length=input_seq_len, strategy="multioutput"
            ),
        ),
    ]
)

forecaster_pipe.fit(y_train, X=x_train, fh=fhzon)

y_predict = forecaster_pipe.predict(fh=fhzon)


fig, ax = plotting.plot_series(
    y_train.tail(60), y_test, y_predict, labels=["Train", "Test", "Prediction"]
)

# %% [markdown]
# ### Prediction on Test Data

# %% [markdown]
# ### Training Score

# %%
cross_validation = SlidingWindowSplitter(
    initial_window=int(y_train.shape[0] * 0.8),
    window_length=input_seq_len + ouput_seq_len,
    step_length=3,
)
losses = [MeanSquaredError(), MeanAbsoluteError(), MeanAbsolutePercentageError()]

results = evaluate(
    forecaster=forecaster, y=y_train, X=x_train, cv=cross_validation, scoring=losses
)

results[
    [
        "test_MeanSquaredError",
        "test_MeanAbsoluteError",
        "test_MeanAbsolutePercentageError",
    ]
].mean()
# Out:
# test_MeanSquaredError               5.125290
# test_MeanAbsoluteError              1.742339
# test_MeanAbsolutePercentageError    0.174301
# dtype: float64

# %% [markdown]
# ### Test Score

# %%
for loss in losses:
    l = loss(y_test.copy(deep=True), y_predict)
    print(f"{loss.name} : {l}")
# Out:
# MeanSquaredError : 2.843696805730708
# MeanAbsoluteError : 1.483075426081245
# MeanAbsolutePercentageError : 0.28509068937471477

# %% [markdown]
# ### Forecasting

# %%
print(f"forecaster.cutoff After Traing + Predict {forecaster.cutoff}")

y_fcasted = forecaster_pipe.update(
    y_test.copy(deep=True), X=x_test, update_params=False
)

print(f"forecaster.cutoff After Traing + Predict {forecaster.cutoff}")

y_fcasted = forecaster_pipe.predict(fh=fhzon)
y_fcasted.head()

fig, ax = plotting.plot_series(
    y_test.copy(deep=True), y_fcasted, labels=["Past", "Forecasted"]
)
# Out:
# forecaster.cutoff After Traing + Predict None
# forecaster.cutoff After Traing + Predict None

# %%
trf_y = TransformedTargetForecaster(
    [
        ("scale_y", TabularToSeriesAdaptor(StandardScaler())),
        (
            "xtransform",
            ForecastingPipeline(
                [
                    ("scale_X", TabularToSeriesAdaptor(Id())),
                    (
                        "forecaster",
                        make_reduction(
                            estimator=LinearRegression(),
                            window_length=24,
                            strategy="multioutput",
                        ),
                    ),
                ]
            ),
        ),
    ]
)
trf_y.fit(y_train, X=x_train, fh=fhzon)

tt = trf_y.predict(fh=fhzon)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 16
#       1 trf_y = TransformedTargetForecaster(
#       2             [
#       3                 ("scale_y", TabularToSeriesAdaptor(StandardScaler())),
#    (...)
#      12                 )
#      13             ])
#      14 trf_y.fit(y_train, X=x_train, fh=fhzon)
# ---> 16 tt=trf_y.predict(fh=fhzon)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sktime\forecasting\base\_base.py:407, in BaseForecaster.predict(self, fh, X)
#     405 # we call the ordinary _predict if no looping/vectorization needed
#     406 if not self._is_vectorized:
# --> 407     y_pred = self._predict(fh=fh, X=X_inner)
#     408 else:
#     409     # otherwise we call the vectorized version of predict
#     410     y_pred = self._vectorize("predict", X=X_inner, fh=fh)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sktime\forecasting\compose\_pipeline.py:1013, in TransformedTargetForecaster._predict(self, fh, X)
#     998 def _predict(self, fh=None, X=None):
#     999     """Forecast time series at future horizon.
#    1000
#    1001     Parameters
#    (...)
#    1011         Point predictions
#    1012     """
# -> 1013     y_pred = self.forecaster_.predict(fh=fh, X=X)
#    1014     # inverse transform y_pred
#    1015     y_pred = self._get_inverse_transform(self.transformers_pre_, y_pred, X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sktime\forecasting\base\_base.py:407, in BaseForecaster.predict(self, fh, X)
#     405 # we call the ordinary _predict if no looping/vectorization needed
#     406 if not self._is_vectorized:
# --> 407     y_pred = self._predict(fh=fh, X=X_inner)
#     408 else:
#     409     # otherwise we call the vectorized version of predict
#     410     y_pred = self._vectorize("predict", X=X_inner, fh=fh)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sktime\forecasting\compose\_pipeline.py:518, in ForecastingPipeline._predict(self, fh, X)
#     503 def _predict(self, fh=None, X=None):
#     504     """Forecast time series at future horizon.
#     505
#     506     Parameters
#    (...)
#     516         Point predictions
#     517     """
# --> 518     X = self._transform(X=X)
#     519     return self.forecaster_.predict(fh, X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sktime\forecasting\compose\_pipeline.py:693, in ForecastingPipeline._transform(self, X, y)
#     691 if self._X is not None and not self.get_tag("ignores-exogeneous-X"):
#     692     for _, _, transformer in self._iter_transformers():
# --> 693         X = transformer.transform(X=X, y=y)
#     694 return X
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sktime\transformations\base.py:533, in BaseTransformer.transform(self, X, y)
#     530 self.check_is_fitted()
#     532 # input check and conversion for X/y
# --> 533 X_inner, y_inner, metadata = self._check_X_y(X=X, y=y, return_metadata=True)
#     535 if not isinstance(X_inner, VectorizedDF):
#     536     Xt = self._transform(X=X_inner, y=y_inner)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sktime\transformations\base.py:874, in BaseTransformer._check_X_y(self, X, y, return_metadata)
#     820 """Check and coerce X/y for fit/transform functions.
#     821
#     822 Parameters
#    (...)
#     871 ValueError if self.get_tag("requires_y")=True but y is None
#     872 """
#     873 if X is None:
# --> 874     raise TypeError("X cannot be None, but found None")
#     876 # skip conversion if it is turned off
#     877 if self.get_config()["input_conversion"] != "on":
#
# TypeError: X cannot be None, but found None

# %%
# Out:
# TransformedTargetForecaster(steps=[('scale_y',
#                                     TabularToSeriesAdaptor(transformer=StandardScaler())),
#                                    ('xtransform',
#                                     ForecastingPipeline(steps=[('scale_X',
#                                                                 TabularToSeriesAdaptor(transformer=Id())),
#                                                                ('forecaster',
#                                                                 MultioutputTabularRegressionForecaster(estimator=LinearRegression(),
#                                                                                                        window_length=24))]))])

# %%
fig, ax = plotting.plot_series(
    y_train.tail(60),
    y_test,
    tt,
    y_predict,
    labels=["Train", "Test", "Prediction1", "Prediction2"],
)
