# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.sanity import *

from src.load_datasets import load_air_quality_data

from src.utils import (
    show_dataset,
    show_series,
    plot_metrics,
    test_train_split,
    seperate_target,
    plot_tf_training_history,
)

from src.features import (
    create_lag_feature,
    create_datetime_feature,
    create_cyclic_feature,
    create_window_feature,
    drop_null_rows,
)

from src.evaluation import evaluate

# %%
np.random.seed(80)
plt.style.use("seaborn-v0_8-darkgrid")
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

# %config InlineBackend.figure_format = 'retina'

# %%
dataframe = (
    load_air_quality_data()
    .pipe(format_datetime, col="Date_Time")
    .pipe(set_index, col="Date_Time")
    .pipe(interpolate_column)
    .pipe(resample_Data, freq="6H")
)

print(f"dataframe shape {dataframe.shape}")

print(dataframe.info())

dataframe.head()
# Out:
# format_datetime: DF Shape (9357, 14)
# set_index: DF Shape (9357, 13)
# interpolate_columns: DF Shape (9357, 13)
# resample_Data: DF Shape (1560, 13)
# dataframe shape (1560, 13)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1560 entries, 2004-03-10 18:00:00 to 2005-04-04 12:00:00
# Freq: 6H
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CO_true      1560 non-null   float64
#  1   CO_sensor    1560 non-null   float64
#  2   NMHC_true    1560 non-null   float64
#  3   C6H6_true    1560 non-null   float64
#  4   NMHC_sensor  1560 non-null   float64
#  5   NOX_true     1560 non-null   float64
#  6   NOX_sensor   1560 non-null   float64
#  7   NO2_true     1560 non-null   float64
#  8   NO2_sensor   1560 non-null   float64
#  9   O3_sensor    1560 non-null   float64
#  10  T            1560 non-null   float64
#  11  RH           1560 non-null   float64
#  12  AH           1560 non-null   float64
# dtypes: float64(13)
# memory usage: 170.6 KB
# None
#                        CO_true    CO_sensor   NMHC_true  C6H6_true  \
# Date_Time
# 2004-03-10 18:00:00   1.966667  1316.500000   86.500000   8.450000
# 2004-03-11 00:00:00 -32.600000  1083.666667   21.166667   2.216667
# 2004-03-11 06:00:00   1.533333  1215.333333   52.666667   5.600000
# 2004-03-11 12:00:00   2.283333  1313.000000  102.000000   8.716667
# 2004-03-11 18:00:00   4.033333  1364.666667  242.166667  15.383333
#
#                      NMHC_sensor    NOX_true   NOX_sensor    NO2_true  \
# Date_Time
# 2004-03-10 18:00:00   912.333333  132.000000  1167.333333  108.833333
# 2004-03-11 00:00:00   595.166667    1.000000  1655.833333   12.500000
# 2004-03-11 06:00:00   778.166667  107.000000  1331.500000   88.833333
# 2004-03-11 12:00:00   923.666667  179.500000  1106.500000  121.166667
# 2004-03-11 18:00:00  1110.833333  232.666667  1015.166667  127.000000
#
#                       NO2_sensor    O3_sensor          T         RH        AH
# Date_Time
# 2004-03-10 18:00:00  1545.500000  1096.000000  12.033333  54.900000  0.765633
# 2004-03-11 00:00:00  1259.333333   575.166667  10.683333  58.900000  0.755017
# 2004-03-11 06:00:00  1411.333333   810.500000  10.550000  58.666667  0.746217
# 2004-03-11 12:00:00  1604.166667   917.833333   8.933333  73.816667  0.843533
# 2004-03-11 18:00:00  1816.500000  1237.500000   9.183333  64.916667  0.758300

# %%
show_dataset(dataframe[:90], columns=["CO_sensor"])

# %%
DT_FEATURES = [
    "dayofweek",
    "quarter",
    "month",
    "year",
    "dayofyear",
    "dayofmonth",
    "weekofyear",
    "dayofweek",
    "is_week_end",
    "is_week_day",
]
CYCLIC_FEATURE = ["day", "month", "year"]
LAGS = [1, 2]
FEATURE_WINDOW_LEN = 3

TARGET_COLUMN = "CO_sensor"
TEST_SIZE = 30

# %%
print(f"dataframe shape {dataframe.shape}")

build_features = lambda df: (
    df.pipe(create_lag_feature, column=TARGET_COLUMN, lags=LAGS)
    .pipe(create_window_feature, column=TARGET_COLUMN, window_len=FEATURE_WINDOW_LEN)
    .pipe(create_datetime_feature, features_name=DT_FEATURES)
    .pipe(create_cyclic_feature, features_name=CYCLIC_FEATURE)
    .pipe(drop_null_rows)
)

df_feat = build_features(dataframe)

print(f"dataframe shape after Feature Union {df_feat.shape}", end="\n\n")

train_data, test_data = test_train_split(df_feat, test_size=TEST_SIZE)

print(f"Train Size after Test_Train Split: {train_data.shape}")
print(f"Test  Size after Test_Train Split: {test_data.shape} ", end="\n\n")

train_x, train_y = seperate_target(train_data, TARGET_COLUMN)
test_x, test_y = seperate_target(test_data, TARGET_COLUMN)

print(f"train_x shape after seperate_target {train_x.shape}")
print(f"train_y shape after seperate_target {train_y.shape}")
print(f"test_x  shape after seperate_target {test_x.shape}")
print(f"test_y  shape after seperate_target {test_y.shape}")
# Out:
# dataframe shape (1560, 13)
# dataframe shape after Feature Union (1557, 32)
#
# Train Size after Test_Train Split: (1527, 32)
# Test  Size after Test_Train Split: (30, 32)
#
# train_x shape after seperate_target (1527, 31)
# train_y shape after seperate_target (1527, 1)
# test_x  shape after seperate_target (30, 31)
# test_y  shape after seperate_target (30, 1)

# %%
resultsDict = {}
predictionsDF = pd.DataFrame(index=test_x.index)

# %% [markdown]
# ### KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

model_name = "KNeighborsRegressor"

estimator_ = Pipeline(
    [
        ("scaler", StandardScaler()),
        (
            "regressor",
            KNeighborsRegressor(n_neighbors=2),
        ),
    ]
)

param_grid = {"regressor__n_neighbors": [2, 3, 5, 7, 12, 15]}

cross_validator = TimeSeriesSplit(n_splits=3)

gsearch = GridSearchCV(
    estimator=estimator_,
    cv=cross_validator,
    param_grid=param_grid,
    refit=True,
    verbose=3,
    n_jobs=1,
)

gsearch.fit(train_x, train_y.to_numpy().flatten())

print(gsearch.best_score_, gsearch.best_params_)

model = gsearch.best_estimator_

yhat = model.predict(test_x)

resultsDict[model_name] = evaluate(test_y[TARGET_COLUMN].to_numpy(), yhat)
predictionsDF[model_name] = yhat
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV 1/3] END ..........regressor__n_neighbors=2;, score=0.882 total time=   0.4s
# [CV 2/3] END ..........regressor__n_neighbors=2;, score=0.835 total time=   0.0s
# [CV 3/3] END ..........regressor__n_neighbors=2;, score=0.849 total time=   0.2s
# [CV 1/3] END ..........regressor__n_neighbors=3;, score=0.892 total time=   0.0s
# [CV 2/3] END ..........regressor__n_neighbors=3;, score=0.829 total time=   0.1s
# [CV 3/3] END ..........regressor__n_neighbors=3;, score=0.873 total time=   0.1s
# [CV 1/3] END ..........regressor__n_neighbors=5;, score=0.897 total time=   0.0s
# [CV 2/3] END ..........regressor__n_neighbors=5;, score=0.820 total time=   0.1s
# [CV 3/3] END ..........regressor__n_neighbors=5;, score=0.896 total time=   0.1s
# [CV 1/3] END ..........regressor__n_neighbors=7;, score=0.893 total time=   0.1s
# [CV 2/3] END ..........regressor__n_neighbors=7;, score=0.810 total time=   0.1s
# [CV 3/3] END ..........regressor__n_neighbors=7;, score=0.903 total time=   0.2s
# [CV 1/3] END .........regressor__n_neighbors=12;, score=0.766 total time=   0.0s
# [CV 2/3] END .........regressor__n_neighbors=12;, score=0.787 total time=   0.0s
# [CV 3/3] END .........regressor__n_neighbors=12;, score=0.905 total time=   0.0s
# [CV 1/3] END .........regressor__n_neighbors=15;, score=0.699 total time=   0.0s
# [CV 2/3] END .........regressor__n_neighbors=15;, score=0.781 total time=   0.2s
# [CV 3/3] END .........regressor__n_neighbors=15;, score=0.910 total time=   0.1s
# 0.8708997506545977 {'regressor__n_neighbors': 5}

# %%
show_series(
    [train_y[-90:], test_y, predictionsDF[model_name]],
    labels=["train", "test", "predict"],
)

# %% [markdown]
# ### Ridge Model

# %%
from sklearn.linear_model import BayesianRidge

model, yhat, model_name = None, None, None
model_name = "BayesianRidge"

model = Pipeline(
    [
        ("scaler", StandardScaler()),
        (
            "regressor",
            BayesianRidge(fit_intercept=True, verbose=True, compute_score=True),
        ),
    ]
)


model.fit(train_x, train_y.to_numpy().flatten())
yhat = model.predict(test_x)

resultsDict[model_name] = evaluate(test_y[TARGET_COLUMN].to_numpy(), yhat)
predictionsDF[model_name] = yhat
# Out:
# Convergence after  7  iterations

# %%
show_series(
    [train_y[-90:], test_y, predictionsDF[model_name]],
    labels=["train", "test", "predict"],
)

# %% [markdown]
# ### LassoCV Regressor

# %%
from sklearn.linear_model import LassoCV

model, yhat, model_name = None, None, None

model_name = "LassoCV"

model = Pipeline(
    [("scaler", StandardScaler()), ("regressor", LassoCV(fit_intercept=True))]
)

model.fit(train_x, train_y.to_numpy().flatten())
yhat = model.predict(test_x)

resultsDict[model_name] = evaluate(test_y[TARGET_COLUMN].to_numpy(), yhat)
predictionsDF[model_name] = yhat

# %%
show_series(
    [train_y[-90:], test_y, predictionsDF[model_name]],
    labels=["train", "test", "predict"],
)

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor


model, yhat, model_name = None, None, None

model_name = "RandomForestRegressor"

# {'max_depth': 9, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}

param_grid = {
    #'bootstrap': [True,False],
    # "max_depth": [7, 8, 9],
    # "min_samples_leaf": [2, 3],
    # "min_samples_split": [7, 8],
    # "n_estimators": [300, 500, 600],
    "max_depth": [9],
    "min_samples_leaf": [2],
    "min_samples_split": [7],
    "n_estimators": [600],
}

estimator_ = RandomForestRegressor(random_state=80)


cross_validator = TimeSeriesSplit(n_splits=3)

gsearch = GridSearchCV(
    estimator=estimator_,
    cv=cross_validator,
    param_grid=param_grid,
    refit=True,
    verbose=3,
    n_jobs=1,
)

# gsearch.fit(train_x_scaled, train_y.to_numpy().flatten())

gsearch.fit(train_x, train_y.to_numpy().flatten())

print(gsearch.best_score_, gsearch.best_params_)

model = gsearch.best_estimator_

yhat = model.predict(test_x)

resultsDict[model_name] = evaluate(test_y[TARGET_COLUMN].to_numpy(), yhat)
predictionsDF[model_name] = yhat
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END max_depth=9, min_samples_leaf=2, min_samples_split=7, n_estimators=600;, score=0.951 total time=   6.2s
# [CV 2/3] END max_depth=9, min_samples_leaf=2, min_samples_split=7, n_estimators=600;, score=0.941 total time=  13.1s
# [CV 3/3] END max_depth=9, min_samples_leaf=2, min_samples_split=7, n_estimators=600;, score=0.958 total time=  20.2s
# 0.9499344808462342 {'max_depth': 9, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 600}

# %%
show_series(
    [train_y[-90:], test_y, predictionsDF[model_name]],
    labels=["train", "test", "predict"],
)

# %% [markdown]
# ### XGB Regressor

# %%
import xgboost as xgb

model, yhat, model_name = None, None, None

model_name = "XGBRegressor"

model = xgb.XGBRegressor(
    objective="reg:squarederror",
    n_estimators=1000,
    max_depth=6,
    learning_rate=0.01,
    tree_method="hist",
    early_stopping_rounds=20,
    eval_metric="mae",
    random_state=1,
)

model.fit(
    train_x, train_y, eval_set=[(train_x, train_y), (test_x, test_y)], verbose=True
)

yhat = model.predict(test_x)

resultsDict[model_name] = evaluate(test_y[TARGET_COLUMN].to_numpy(), yhat)

predictionsDF[model_name] = yhat

# resultsDF.head()

fig, ax = plt.subplots()
epochs = len(model.evals_result()["validation_0"]["mae"])
x_axis = range(0, epochs)
ax.plot(x_axis, model.evals_result()["validation_0"]["mae"], label="Train")
ax.plot(x_axis, model.evals_result()["validation_1"]["mae"], label="Test")
ax.legend()
# Out:
# [0]	validation_0-mae:1051.45547	validation_1-mae:1015.76414
# [1]	validation_0-mae:1040.98318	validation_1-mae:1005.89873
# [2]	validation_0-mae:1030.61688	validation_1-mae:996.15987
# [3]	validation_0-mae:1020.36107	validation_1-mae:986.45644
# [4]	validation_0-mae:1010.20928	validation_1-mae:976.93242
# [5]	validation_0-mae:1000.14933	validation_1-mae:967.40663
# [6]	validation_0-mae:990.19594	validation_1-mae:957.99025
# [7]	validation_0-mae:980.34439	validation_1-mae:948.74883
# [8]	validation_0-mae:970.59116	validation_1-mae:939.48778
# [9]	validation_0-mae:960.92366	validation_1-mae:930.38198
# [10]	validation_0-mae:951.36393	validation_1-mae:921.30604
# [11]	validation_0-mae:941.88874	validation_1-mae:912.25617
# [12]	validation_0-mae:932.51856	validation_1-mae:903.19560
# [13]	validation_0-mae:923.23905	validation_1-mae:894.41251
# [14]	validation_0-mae:914.04371	validation_1-mae:885.59448
# [15]	validation_0-mae:904.94884	validation_1-mae:876.93544
# [16]	validation_0-mae:895.94241	validation_1-mae:868.25899
# [17]	validation_0-mae:887.02996	validation_1-mae:859.64167
# [18]	validation_0-mae:878.20371	validation_1-mae:851.26584
# [19]	validation_0-mae:869.46598	validation_1-mae:842.97268
# [20]	validation_0-mae:860.81589	validation_1-mae:834.78881
# [21]	validation_0-mae:852.25272	validation_1-mae:826.66164
# [22]	validation_0-mae:843.77311	validation_1-mae:818.61753
# [23]	validation_0-mae:835.37871	validation_1-mae:810.55218
# [24]	validation_0-mae:827.06696	validation_1-mae:802.77685
# [25]	validation_0-mae:818.84247	validation_1-mae:794.92989
# [26]	validation_0-mae:810.69463	validation_1-mae:787.32884
# [27]	validation_0-mae:802.63424	validation_1-mae:779.68013
# [28]	validation_0-mae:794.64781	validation_1-mae:772.28775
# [29]	validation_0-mae:786.74730	validation_1-mae:764.79116
# [30]	validation_0-mae:778.91776	validation_1-mae:757.44341
# [31]	validation_0-mae:771.16876	validation_1-mae:750.09035
# [32]	validation_0-mae:763.49642	validation_1-mae:742.88936
# [33]	validation_0-mae:755.91005	validation_1-mae:735.56798
# [34]	validation_0-mae:748.39160	validation_1-mae:728.47732
# [35]	validation_0-mae:740.94932	validation_1-mae:721.30861
# [36]	validation_0-mae:733.58247	validation_1-mae:714.29828
# [37]	validation_0-mae:726.28586	validation_1-mae:707.34604
# [38]	validation_0-mae:719.06687	validation_1-mae:700.32710
# [39]	validation_0-mae:711.92031	validation_1-mae:693.37191
# [40]	validation_0-mae:704.84848	validation_1-mae:686.49369
# [41]	validation_0-mae:697.84251	validation_1-mae:679.94700
# [42]	validation_0-mae:690.91285	validation_1-mae:673.21766
# [43]	validation_0-mae:684.04426	validation_1-mae:666.68157
# [44]	validation_0-mae:677.24633	validation_1-mae:660.05894
# [45]	validation_0-mae:670.51856	validation_1-mae:653.63901
# [46]	validation_0-mae:663.86110	validation_1-mae:647.17005
# [47]	validation_0-mae:657.26942	validation_1-mae:640.68931
# [48]	validation_0-mae:650.73700	validation_1-mae:634.35227
# [49]	validation_0-mae:644.27603	validation_1-mae:628.00252
# [50]	validation_0-mae:637.87543	validation_1-mae:621.89290
# [51]	validation_0-mae:631.53618	validation_1-mae:615.73128
# [52]	validation_0-mae:625.26255	validation_1-mae:609.85564
# [53]	validation_0-mae:619.05316	validation_1-mae:603.86356
# [54]	validation_0-mae:612.91104	validation_1-mae:597.78432
# [55]	validation_0-mae:606.82563	validation_1-mae:591.79143
# [56]	validation_0-mae:600.80153	validation_1-mae:585.99489
# [57]	validation_0-mae:594.83669	validation_1-mae:580.08635
# [58]	validation_0-mae:588.93579	validation_1-mae:574.26849
# [59]	validation_0-mae:583.08913	validation_1-mae:568.48863
# [60]	validation_0-mae:577.29677	validation_1-mae:562.76628
# [61]	validation_0-mae:571.56268	validation_1-mae:557.15682
# [62]	validation_0-mae:565.88469	validation_1-mae:551.54795
# [63]	validation_0-mae:560.26401	validation_1-mae:546.04989
# [64]	validation_0-mae:554.70064	validation_1-mae:540.54460
# [65]	validation_0-mae:549.19169	validation_1-mae:535.17716
# [66]	validation_0-mae:543.73936	validation_1-mae:529.83880
# [67]	validation_0-mae:538.33916	validation_1-mae:524.57713
# [68]	validation_0-mae:532.99938	validation_1-mae:519.21198
# [69]	validation_0-mae:527.70773	validation_1-mae:514.03165
# [70]	validation_0-mae:522.46327	validation_1-mae:508.91616
# [71]	validation_0-mae:517.27351	validation_1-mae:503.79588
# [72]	validation_0-mae:512.14808	validation_1-mae:498.60469
# [73]	validation_0-mae:507.06180	validation_1-mae:493.64740
# [74]	validation_0-mae:502.02527	validation_1-mae:488.67518
# [75]	validation_0-mae:497.03617	validation_1-mae:483.80901
# [76]	validation_0-mae:492.10849	validation_1-mae:478.78922
# [77]	validation_0-mae:487.22216	validation_1-mae:473.90858
# [78]	validation_0-mae:482.39171	validation_1-mae:469.11892
# [79]	validation_0-mae:477.60954	validation_1-mae:464.24000
# [80]	validation_0-mae:472.86317	validation_1-mae:459.59680
# [81]	validation_0-mae:468.17309	validation_1-mae:454.93689
# [82]	validation_0-mae:463.52683	validation_1-mae:450.37103
# [83]	validation_0-mae:458.92643	validation_1-mae:445.83958
# [84]	validation_0-mae:454.37610	validation_1-mae:441.23690
# [85]	validation_0-mae:449.87160	validation_1-mae:436.83881
# [86]	validation_0-mae:445.40583	validation_1-mae:432.53668
# [87]	validation_0-mae:440.98537	validation_1-mae:428.18333
# [88]	validation_0-mae:436.61670	validation_1-mae:423.55461
# [89]	validation_0-mae:432.28524	validation_1-mae:419.38631
# [90]	validation_0-mae:428.00250	validation_1-mae:415.22678
# [91]	validation_0-mae:423.76010	validation_1-mae:411.02047
# [92]	validation_0-mae:419.56361	validation_1-mae:406.88723
# [93]	validation_0-mae:415.40418	validation_1-mae:402.70391
# [94]	validation_0-mae:411.28740	validation_1-mae:398.56091
# [95]	validation_0-mae:407.21226	validation_1-mae:394.51300
# [96]	validation_0-mae:403.17813	validation_1-mae:390.32827
# [97]	validation_0-mae:399.18365	validation_1-mae:386.28445
# [98]	validation_0-mae:395.23266	validation_1-mae:382.38239
# [99]	validation_0-mae:391.31837	validation_1-mae:378.52762
# [100]	validation_0-mae:387.44324	validation_1-mae:374.64041
# [101]	validation_0-mae:383.60702	validation_1-mae:370.71645
# [102]	validation_0-mae:379.80863	validation_1-mae:366.91582
# [103]	validation_0-mae:376.04708	validation_1-mae:363.11660
# [104]	validation_0-mae:372.32571	validation_1-mae:359.42795
# [105]	validation_0-mae:368.63872	validation_1-mae:355.75874
# [106]	validation_0-mae:364.98620	validation_1-mae:352.21285
# [107]	validation_0-mae:361.37321	validation_1-mae:348.67464
# [108]	validation_0-mae:357.79107	validation_1-mae:345.10554
# [109]	validation_0-mae:354.24936	validation_1-mae:341.61710
# [110]	validation_0-mae:350.74226	validation_1-mae:338.12714
# [111]	validation_0-mae:347.26949	validation_1-mae:334.78685
# [112]	validation_0-mae:343.83380	validation_1-mae:331.37758
# [113]	validation_0-mae:340.43477	validation_1-mae:327.94014
# [114]	validation_0-mae:337.06425	validation_1-mae:324.61911
# [115]	validation_0-mae:333.72963	validation_1-mae:321.30861
# [116]	validation_0-mae:330.42578	validation_1-mae:318.16372
# [117]	validation_0-mae:327.15608	validation_1-mae:314.93850
# [118]	validation_0-mae:323.91991	validation_1-mae:311.57380
# [119]	validation_0-mae:320.71642	validation_1-mae:308.36165
# [120]	validation_0-mae:317.54089	validation_1-mae:305.24378
# [121]	validation_0-mae:314.39739	validation_1-mae:302.25110
# [122]	validation_0-mae:311.28664	validation_1-mae:299.12495
# [123]	validation_0-mae:308.21085	validation_1-mae:295.97839
# [124]	validation_0-mae:305.16121	validation_1-mae:292.90960
# [125]	validation_0-mae:302.14356	validation_1-mae:289.90178
# [126]	validation_0-mae:299.15219	validation_1-mae:287.05809
# [127]	validation_0-mae:296.19624	validation_1-mae:284.02205
# [128]	validation_0-mae:293.26564	validation_1-mae:281.06640
# [129]	validation_0-mae:290.36800	validation_1-mae:278.10070
# [130]	validation_0-mae:287.49393	validation_1-mae:275.36652
# [131]	validation_0-mae:284.65423	validation_1-mae:272.44997
# [132]	validation_0-mae:281.83876	validation_1-mae:269.75609
# [133]	validation_0-mae:279.04885	validation_1-mae:266.82376
# [134]	validation_0-mae:276.29329	validation_1-mae:264.00866
# [135]	validation_0-mae:273.56689	validation_1-mae:261.23075
# [136]	validation_0-mae:270.86609	validation_1-mae:258.37625
# [137]	validation_0-mae:268.19451	validation_1-mae:255.68561
# [138]	validation_0-mae:265.54194	validation_1-mae:252.87527
# [139]	validation_0-mae:262.92178	validation_1-mae:250.20530
# [140]	validation_0-mae:260.32305	validation_1-mae:247.71229
# [141]	validation_0-mae:257.75763	validation_1-mae:245.20294
# [142]	validation_0-mae:255.21069	validation_1-mae:242.76290
# [143]	validation_0-mae:252.69182	validation_1-mae:240.02444
# [144]	validation_0-mae:250.19586	validation_1-mae:237.50303
# [145]	validation_0-mae:247.72859	validation_1-mae:235.05625
# [146]	validation_0-mae:245.28201	validation_1-mae:232.61500
# [147]	validation_0-mae:242.86247	validation_1-mae:230.15192
# [148]	validation_0-mae:240.46370	validation_1-mae:227.85256
# [149]	validation_0-mae:238.09460	validation_1-mae:225.53590
# [150]	validation_0-mae:235.74672	validation_1-mae:223.08714
# [151]	validation_0-mae:233.41763	validation_1-mae:220.76811
# [152]	validation_0-mae:231.11560	validation_1-mae:218.41735
# [153]	validation_0-mae:228.83808	validation_1-mae:216.12112
# [154]	validation_0-mae:226.58073	validation_1-mae:213.83130
# [155]	validation_0-mae:224.34845	validation_1-mae:211.43297
# [156]	validation_0-mae:222.13397	validation_1-mae:209.09374
# [157]	validation_0-mae:219.94201	validation_1-mae:206.87917
# [158]	validation_0-mae:217.77480	validation_1-mae:204.68249
# [159]	validation_0-mae:215.62575	validation_1-mae:202.60910
# [160]	validation_0-mae:213.49980	validation_1-mae:200.48301
# [161]	validation_0-mae:211.39517	validation_1-mae:198.47156
# [162]	validation_0-mae:209.31465	validation_1-mae:196.30105
# [163]	validation_0-mae:207.25309	validation_1-mae:194.14322
# [164]	validation_0-mae:205.20968	validation_1-mae:192.01072
# [165]	validation_0-mae:203.18501	validation_1-mae:190.07519
# [166]	validation_0-mae:201.18218	validation_1-mae:188.08327
# [167]	validation_0-mae:199.20231	validation_1-mae:186.00781
# [168]	validation_0-mae:197.24080	validation_1-mae:184.07295
# [169]	validation_0-mae:195.30151	validation_1-mae:182.05263
# [170]	validation_0-mae:193.37358	validation_1-mae:180.07644
# [171]	validation_0-mae:191.46666	validation_1-mae:178.07049
# [172]	validation_0-mae:189.57928	validation_1-mae:176.09095
# [173]	validation_0-mae:187.71328	validation_1-mae:174.20268
# [174]	validation_0-mae:185.86390	validation_1-mae:172.36331
# [175]	validation_0-mae:184.03194	validation_1-mae:170.47786
# [176]	validation_0-mae:182.22086	validation_1-mae:168.65358
# [177]	validation_0-mae:180.42502	validation_1-mae:166.92676
# [178]	validation_0-mae:178.64788	validation_1-mae:165.16686
# [179]	validation_0-mae:176.88934	validation_1-mae:163.39553
# [180]	validation_0-mae:175.14650	validation_1-mae:161.58245
# [181]	validation_0-mae:173.42356	validation_1-mae:159.77824
# [182]	validation_0-mae:171.71584	validation_1-mae:157.96833
# [183]	validation_0-mae:170.02320	validation_1-mae:156.19171
# [184]	validation_0-mae:168.35187	validation_1-mae:154.56437
# [185]	validation_0-mae:166.69755	validation_1-mae:152.83356
# [186]	validation_0-mae:165.05738	validation_1-mae:151.08593
# [187]	validation_0-mae:163.43353	validation_1-mae:149.45312
# [188]	validation_0-mae:161.82681	validation_1-mae:147.67996
# [189]	validation_0-mae:160.23525	validation_1-mae:145.90617
# [190]	validation_0-mae:158.65724	validation_1-mae:144.22964
# [191]	validation_0-mae:157.09742	validation_1-mae:142.66521
# [192]	validation_0-mae:155.55343	validation_1-mae:141.07370
# [193]	validation_0-mae:154.02513	validation_1-mae:139.34229
# [194]	validation_0-mae:152.51277	validation_1-mae:137.77338
# [195]	validation_0-mae:151.01369	validation_1-mae:136.25533
# [196]	validation_0-mae:149.52896	validation_1-mae:134.71966
# [197]	validation_0-mae:148.06154	validation_1-mae:133.24715
# [198]	validation_0-mae:146.60555	validation_1-mae:131.77341
# [199]	validation_0-mae:145.16508	validation_1-mae:130.27246
# [200]	validation_0-mae:143.74230	validation_1-mae:128.84295
# [201]	validation_0-mae:142.32930	validation_1-mae:127.36703
# [202]	validation_0-mae:140.93160	validation_1-mae:125.96834
# [203]	validation_0-mae:139.55004	validation_1-mae:124.41206
# [204]	validation_0-mae:138.18094	validation_1-mae:123.04450
# [205]	validation_0-mae:136.82570	validation_1-mae:121.53086
# [206]	validation_0-mae:135.48159	validation_1-mae:120.15452
# [207]	validation_0-mae:134.14986	validation_1-mae:118.77049
# [208]	validation_0-mae:132.83293	validation_1-mae:117.45577
# [209]	validation_0-mae:131.53155	validation_1-mae:115.96696
# [210]	validation_0-mae:130.24168	validation_1-mae:114.60951
# [211]	validation_0-mae:128.96259	validation_1-mae:113.13734
# [212]	validation_0-mae:127.69722	validation_1-mae:111.77244
# [213]	validation_0-mae:126.44246	validation_1-mae:110.52811
# [214]	validation_0-mae:125.20022	validation_1-mae:109.23326
# [215]	validation_0-mae:123.97010	validation_1-mae:108.01110
# [216]	validation_0-mae:122.75273	validation_1-mae:106.73874
# [217]	validation_0-mae:121.54818	validation_1-mae:105.42775
# [218]	validation_0-mae:120.35827	validation_1-mae:104.19041
# [219]	validation_0-mae:119.17604	validation_1-mae:102.83546
# [220]	validation_0-mae:118.00769	validation_1-mae:101.57251
# [221]	validation_0-mae:116.84867	validation_1-mae:100.25376
# [222]	validation_0-mae:115.70389	validation_1-mae:99.13735
# [223]	validation_0-mae:114.56847	validation_1-mae:97.89446
# [224]	validation_0-mae:113.44612	validation_1-mae:96.64310
# [225]	validation_0-mae:112.33530	validation_1-mae:95.39286
# [226]	validation_0-mae:111.23399	validation_1-mae:94.25744
# [227]	validation_0-mae:110.14516	validation_1-mae:93.03311
# [228]	validation_0-mae:109.06895	validation_1-mae:91.99757
# [229]	validation_0-mae:107.99898	validation_1-mae:90.99577
# [230]	validation_0-mae:106.94009	validation_1-mae:89.90398
# [231]	validation_0-mae:105.89340	validation_1-mae:88.63366
# [232]	validation_0-mae:104.85691	validation_1-mae:87.54871
# [233]	validation_0-mae:103.82777	validation_1-mae:86.48609
# [234]	validation_0-mae:102.81261	validation_1-mae:85.41749
# [235]	validation_0-mae:101.80823	validation_1-mae:84.41396
# [236]	validation_0-mae:100.81244	validation_1-mae:83.20117
# [237]	validation_0-mae:99.82634	validation_1-mae:82.21545
# [238]	validation_0-mae:98.84832	validation_1-mae:81.12042
# [239]	validation_0-mae:97.88101	validation_1-mae:80.01169
# [240]	validation_0-mae:96.92498	validation_1-mae:78.93995
# [241]	validation_0-mae:95.98025	validation_1-mae:78.05224
# [242]	validation_0-mae:95.04428	validation_1-mae:77.06517
# [243]	validation_0-mae:94.11761	validation_1-mae:76.00202
# [244]	validation_0-mae:93.20099	validation_1-mae:75.04728
# [245]	validation_0-mae:92.29409	validation_1-mae:74.07645
# [246]	validation_0-mae:91.39661	validation_1-mae:72.97120
# [247]	validation_0-mae:90.50487	validation_1-mae:72.09414
# [248]	validation_0-mae:89.62369	validation_1-mae:71.11059
# [249]	validation_0-mae:88.75254	validation_1-mae:70.20279
# [250]	validation_0-mae:87.88904	validation_1-mae:69.30232
# [251]	validation_0-mae:87.03491	validation_1-mae:68.39052
# [252]	validation_0-mae:86.19295	validation_1-mae:67.40619
# [253]	validation_0-mae:85.35524	validation_1-mae:66.52713
# [254]	validation_0-mae:84.53171	validation_1-mae:65.57121
# [255]	validation_0-mae:83.71393	validation_1-mae:64.65219
# [256]	validation_0-mae:82.90316	validation_1-mae:63.79822
# [257]	validation_0-mae:82.10516	validation_1-mae:62.92006
# [258]	validation_0-mae:81.31205	validation_1-mae:62.14890
# [259]	validation_0-mae:80.52759	validation_1-mae:61.37715
# [260]	validation_0-mae:79.75285	validation_1-mae:60.60529
# [261]	validation_0-mae:78.98391	validation_1-mae:59.77944
# [262]	validation_0-mae:78.22276	validation_1-mae:59.02982
# [263]	validation_0-mae:77.46976	validation_1-mae:58.26145
# [264]	validation_0-mae:76.72494	validation_1-mae:57.44797
# [265]	validation_0-mae:75.98808	validation_1-mae:56.70398
# [266]	validation_0-mae:75.25778	validation_1-mae:55.93160
# [267]	validation_0-mae:74.53354	validation_1-mae:55.22528
# [268]	validation_0-mae:73.81966	validation_1-mae:54.45135
# [269]	validation_0-mae:73.11392	validation_1-mae:53.69474
# [270]	validation_0-mae:72.41571	validation_1-mae:53.03523
# [271]	validation_0-mae:71.72466	validation_1-mae:52.38374
# [272]	validation_0-mae:71.04169	validation_1-mae:51.76902
# [273]	validation_0-mae:70.36537	validation_1-mae:51.12730
# [274]	validation_0-mae:69.69556	validation_1-mae:50.46602
# [275]	validation_0-mae:69.03265	validation_1-mae:49.77214
# [276]	validation_0-mae:68.37690	validation_1-mae:49.23203
# [277]	validation_0-mae:67.72770	validation_1-mae:48.69537
# [278]	validation_0-mae:67.08383	validation_1-mae:48.11324
# [279]	validation_0-mae:66.44900	validation_1-mae:47.58813
# [280]	validation_0-mae:65.81917	validation_1-mae:47.04287
# [281]	validation_0-mae:65.19862	validation_1-mae:46.59036
# [282]	validation_0-mae:64.58249	validation_1-mae:46.08064
# [283]	validation_0-mae:63.97319	validation_1-mae:45.56578
# [284]	validation_0-mae:63.37305	validation_1-mae:45.08531
# [285]	validation_0-mae:62.77885	validation_1-mae:44.59057
# [286]	validation_0-mae:62.19319	validation_1-mae:44.11953
# [287]	validation_0-mae:61.61312	validation_1-mae:43.62844
# [288]	validation_0-mae:61.03984	validation_1-mae:43.17828
# [289]	validation_0-mae:60.46970	validation_1-mae:42.73604
# [290]	validation_0-mae:59.91079	validation_1-mae:42.24394
# [291]	validation_0-mae:59.35805	validation_1-mae:41.79899
# [292]	validation_0-mae:58.81001	validation_1-mae:41.32919
# [293]	validation_0-mae:58.26910	validation_1-mae:40.85100
# [294]	validation_0-mae:57.73360	validation_1-mae:40.38922
# [295]	validation_0-mae:57.20683	validation_1-mae:39.99497
# [296]	validation_0-mae:56.68433	validation_1-mae:39.54211
# [297]	validation_0-mae:56.17011	validation_1-mae:39.12265
# [298]	validation_0-mae:55.65513	validation_1-mae:38.74590
# [299]	validation_0-mae:55.15059	validation_1-mae:38.37985
# [300]	validation_0-mae:54.65382	validation_1-mae:38.02094
# [301]	validation_0-mae:54.16098	validation_1-mae:37.60734
# [302]	validation_0-mae:53.67610	validation_1-mae:37.19229
# [303]	validation_0-mae:53.19327	validation_1-mae:36.87190
# [304]	validation_0-mae:52.71767	validation_1-mae:36.49078
# [305]	validation_0-mae:52.24647	validation_1-mae:36.18953
# [306]	validation_0-mae:51.78171	validation_1-mae:35.89119
# [307]	validation_0-mae:51.32059	validation_1-mae:35.58345
# [308]	validation_0-mae:50.86308	validation_1-mae:35.24609
# [309]	validation_0-mae:50.41483	validation_1-mae:34.95568
# [310]	validation_0-mae:49.97132	validation_1-mae:34.66949
# [311]	validation_0-mae:49.53237	validation_1-mae:34.36908
# [312]	validation_0-mae:49.09778	validation_1-mae:34.03865
# [313]	validation_0-mae:48.67282	validation_1-mae:33.76096
# [314]	validation_0-mae:48.24937	validation_1-mae:33.50370
# [315]	validation_0-mae:47.83559	validation_1-mae:33.29626
# [316]	validation_0-mae:47.42340	validation_1-mae:33.05433
# [317]	validation_0-mae:47.01671	validation_1-mae:32.81551
# [318]	validation_0-mae:46.61720	validation_1-mae:32.64184
# [319]	validation_0-mae:46.21907	validation_1-mae:32.43803
# [320]	validation_0-mae:45.83055	validation_1-mae:32.25929
# [321]	validation_0-mae:45.44412	validation_1-mae:32.11573
# [322]	validation_0-mae:45.06323	validation_1-mae:31.97862
# [323]	validation_0-mae:44.68558	validation_1-mae:31.80991
# [324]	validation_0-mae:44.31337	validation_1-mae:31.66991
# [325]	validation_0-mae:43.94941	validation_1-mae:31.54485
# [326]	validation_0-mae:43.58543	validation_1-mae:31.45432
# [327]	validation_0-mae:43.23108	validation_1-mae:31.33159
# [328]	validation_0-mae:42.87783	validation_1-mae:31.24912
# [329]	validation_0-mae:42.52664	validation_1-mae:31.16089
# [330]	validation_0-mae:42.18517	validation_1-mae:31.04037
# [331]	validation_0-mae:41.84200	validation_1-mae:30.94080
# [332]	validation_0-mae:41.50697	validation_1-mae:30.85024
# [333]	validation_0-mae:41.17504	validation_1-mae:30.75344
# [334]	validation_0-mae:40.84494	validation_1-mae:30.65797
# [335]	validation_0-mae:40.51883	validation_1-mae:30.57170
# [336]	validation_0-mae:40.19870	validation_1-mae:30.51950
# [337]	validation_0-mae:39.88085	validation_1-mae:30.43556
# [338]	validation_0-mae:39.57426	validation_1-mae:30.33602
# [339]	validation_0-mae:39.26859	validation_1-mae:30.25410
# [340]	validation_0-mae:38.96276	validation_1-mae:30.17024
# [341]	validation_0-mae:38.66411	validation_1-mae:30.08260
# [342]	validation_0-mae:38.36748	validation_1-mae:29.99792
# [343]	validation_0-mae:38.07803	validation_1-mae:29.92672
# [344]	validation_0-mae:37.78887	validation_1-mae:29.86929
# [345]	validation_0-mae:37.50458	validation_1-mae:29.80740
# [346]	validation_0-mae:37.22577	validation_1-mae:29.73225
# [347]	validation_0-mae:36.94757	validation_1-mae:29.67675
# [348]	validation_0-mae:36.67225	validation_1-mae:29.61445
# [349]	validation_0-mae:36.40106	validation_1-mae:29.54335
# [350]	validation_0-mae:36.13619	validation_1-mae:29.48130
# [351]	validation_0-mae:35.87306	validation_1-mae:29.42162
# [352]	validation_0-mae:35.61140	validation_1-mae:29.36923
# [353]	validation_0-mae:35.35158	validation_1-mae:29.31176
# [354]	validation_0-mae:35.09644	validation_1-mae:29.26052
# [355]	validation_0-mae:34.84430	validation_1-mae:29.20715
# [356]	validation_0-mae:34.59144	validation_1-mae:29.16480
# [357]	validation_0-mae:34.34734	validation_1-mae:29.12929
# [358]	validation_0-mae:34.10544	validation_1-mae:29.08746
# [359]	validation_0-mae:33.86818	validation_1-mae:29.04753
# [360]	validation_0-mae:33.63462	validation_1-mae:29.01913
# [361]	validation_0-mae:33.40202	validation_1-mae:29.00133
# [362]	validation_0-mae:33.17383	validation_1-mae:28.98737
# [363]	validation_0-mae:32.94769	validation_1-mae:28.99495
# [364]	validation_0-mae:32.72646	validation_1-mae:28.99188
# [365]	validation_0-mae:32.50916	validation_1-mae:29.01268
# [366]	validation_0-mae:32.29331	validation_1-mae:29.01788
# [367]	validation_0-mae:32.07860	validation_1-mae:29.02548
# [368]	validation_0-mae:31.87249	validation_1-mae:29.02247
# [369]	validation_0-mae:31.67105	validation_1-mae:29.03591
# [370]	validation_0-mae:31.46645	validation_1-mae:29.04094
# [371]	validation_0-mae:31.26858	validation_1-mae:29.03161
# [372]	validation_0-mae:31.07021	validation_1-mae:29.02940
# [373]	validation_0-mae:30.87251	validation_1-mae:29.03129
# [374]	validation_0-mae:30.68009	validation_1-mae:29.08196
# [375]	validation_0-mae:30.48678	validation_1-mae:29.06977
# [376]	validation_0-mae:30.29596	validation_1-mae:29.10865
# [377]	validation_0-mae:30.10780	validation_1-mae:29.09714
# [378]	validation_0-mae:29.91907	validation_1-mae:29.12223
# [379]	validation_0-mae:29.73914	validation_1-mae:29.16132
# [380]	validation_0-mae:29.55686	validation_1-mae:29.15160
# [381]	validation_0-mae:29.37799	validation_1-mae:29.14194

# %%
show_series(
    [train_y[-90:], test_y, predictionsDF[model_name]],
    labels=["train", "test", "predict"],
)

# %% [markdown]
# ### LGBM

# %%
import lightgbm as lgb

model, yhat, model_name = None, None, None

model_name = "LGBMRegressor"

hyper_params = {
    "task": "train",
    "boosting_type": "gbdt",
    "objective": "regression",
    "metric": ["mae", "l2"],
    "learning_rate": 0.005,
    "feature_fraction": 0.9,
    "bagging_fraction": 0.7,
    "bagging_freq": 10,
    "verbose": 0,
    "max_depth": 8,
    "num_leaves": 128,
    "max_bin": 512,
    "num_iterations": 10000,
}

model = lgb.LGBMRegressor()

model.fit(
    train_x,
    train_y,
    eval_set=[(train_x, train_y), (test_x, test_y)],
    eval_metric="mae",
    callbacks=[lgb.early_stopping(stopping_rounds=5000), lgb.log_evaluation()],
)


yhat = model.predict(test_x, num_iteration=model.best_iteration_)

resultsDict[model_name] = evaluate(test_y[TARGET_COLUMN].to_numpy(), yhat)

predictionsDF[model_name] = yhat
# Out:
# [1]	training's l1: 178.526	training's l2: 76839	valid_1's l1: 112.286	valid_1's l2: 15246
# Training until validation scores don't improve for 5000 rounds
# [2]	training's l1: 161.934	training's l2: 62998.5	valid_1's l1: 102.199	valid_1's l2: 12599.6
# [3]	training's l1: 147.126	training's l2: 51831.2	valid_1's l1: 90.5496	valid_1's l2: 9920.85
# [4]	training's l1: 133.661	training's l2: 42544.9	valid_1's l1: 81.3704	valid_1's l2: 7975.06
# [5]	training's l1: 121.727	training's l2: 35027.5	valid_1's l1: 73.1762	valid_1's l2: 6462.99
# [6]	training's l1: 110.932	training's l2: 28854.4	valid_1's l1: 65.5321	valid_1's l2: 5267.51
# [7]	training's l1: 101.229	training's l2: 23861.6	valid_1's l1: 58.4583	valid_1's l2: 4263.75
# [8]	training's l1: 92.4076	training's l2: 19750.4	valid_1's l1: 52.4594	valid_1's l2: 3548.02
# [9]	training's l1: 84.684	training's l2: 16366	valid_1's l1: 48.0425	valid_1's l2: 3082.4
# [10]	training's l1: 77.7836	training's l2: 13667	valid_1's l1: 42.3093	valid_1's l2: 2549.65
# [11]	training's l1: 71.4108	training's l2: 11374.5	valid_1's l1: 39.4447	valid_1's l2: 2245.07
# [97]	training's l1: 8.71371	training's l2: 127.634	valid_1's l1: 40.9859	valid_1's l2: 2451.57
# [98]	training's l1: 8.62388	training's l2: 125.266	valid_1's l1: 40.9537	valid_1's l2: 2446.56
# [99]	training's l1: 8.55302	training's l2: 123.105	valid_1's l1: 40.966	valid_1's l2: 2450.36
# [100]	training's l1: 8.4664	training's l2: 120.568	valid_1's l1: 40.9308	valid_1's l2: 2450.55
# Did not meet early stopping. Best iteration is:
# [100]	training's l1: 8.4664	training's l2: 120.568	valid_1's l1: 40.9308	valid_1's l2: 2450.55

# %%
show_series(
    [train_y[-90:], test_y, predictionsDF[model_name]],
    labels=["train", "test", "predict"],
)

# %% [markdown]
# ### CatBoost

# %%
import catboost

model, yhat, model_name = None, None, None

model_name = "CatBoostRegressor"

model = catboost.CatBoostRegressor(learning_rate=0.1, depth=4, iterations=1000)

train_pool = catboost.Pool(train_x, train_y)
test_pool = catboost.Pool(test_x, test_y)

grid = {
    #    'learning_rate': [0.03, 0.1],
    #    'depth':[4, 6, 10],
    #    'l2_leaf_reg': [1, 3, 5, 7, 9]
    "l2_leaf_reg": [3, 5]
}

grid_search_results = model.grid_search(
    grid, train_pool, shuffle=False, verbose=3, refit=True, plot=False
)


print(grid_search_results["params"])

yhat = model.predict(test_x)

resultsDict[model_name] = evaluate(test_y[TARGET_COLUMN].to_numpy(), yhat)

predictionsDF[model_name] = yhat
# Out:
# 0:	learn: 988.9457226	test: 997.8142567	best: 997.8142567 (0)	total: 164ms	remaining: 2m 44s
# 1:	learn: 897.5847598	test: 907.2128277	best: 907.2128277 (1)	total: 170ms	remaining: 1m 24s
# 2:	learn: 817.8353031	test: 826.7909710	best: 826.7909710 (2)	total: 175ms	remaining: 58.3s
# 3:	learn: 740.9488537	test: 748.5416818	best: 748.5416818 (3)	total: 180ms	remaining: 44.9s
# 4:	learn: 675.5607220	test: 685.4291596	best: 685.4291596 (4)	total: 186ms	remaining: 37s
# 5:	learn: 614.1322738	test: 621.9772403	best: 621.9772403 (5)	total: 191ms	remaining: 31.6s
# 6:	learn: 559.2674534	test: 574.0972343	best: 574.0972343 (6)	total: 196ms	remaining: 27.7s
# 7:	learn: 507.9989593	test: 526.6644054	best: 526.6644054 (7)	total: 209ms	remaining: 25.9s
# 8:	learn: 462.8350811	test: 484.1999929	best: 484.1999929 (8)	total: 224ms	remaining: 24.7s
# 9:	learn: 420.3115996	test: 442.1371305	best: 442.1371305 (9)	total: 233ms	remaining: 23s
# 10:	learn: 383.3223769	test: 417.0206126	best: 417.0206126 (10)	total: 243ms	remaining: 21.8s
# 11:	learn: 348.6863635	test: 386.6163379	best: 386.6163379 (11)	total: 251ms	remaining: 20.7s
# 12:	learn: 317.6951417	test: 360.1264387	best: 360.1264387 (12)	total: 270ms	remaining: 20.5s
# 13:	learn: 289.6578047	test: 337.4479666	best: 337.4479666 (13)	total: 301ms	remaining: 21.2s
# 14:	learn: 265.6424120	test: 305.6724318	best: 305.6724318 (14)	total: 356ms	remaining: 23.4s
# 352:	learn: 21.2748823	test: 60.6725287	best: 60.5938104 (343)	total: 5.99s	remaining: 11s
# 353:	learn: 21.2535643	test: 60.6803895	best: 60.5938104 (343)	total: 6s	remaining: 10.9s
# 354:	learn: 21.1920249	test: 60.6830965	best: 60.5938104 (343)	total: 6.01s	remaining: 10.9s
# 355:	learn: 21.1638330	test: 60.6707412	best: 60.5938104 (343)	total: 6.01s	remaining: 10.9s
# 356:	learn: 21.1444410	test: 60.6674483	best: 60.5938104 (343)	total: 6.02s	remaining: 10.8s
# 357:	learn: 21.0915045	test: 60.6981768	best: 60.5938104 (343)	total: 6.02s	remaining: 10.8s
# 358:	learn: 21.0497850	test: 60.7453798	best: 60.5938104 (343)	total: 6.03s	remaining: 10.8s
# 359:	learn: 20.9900296	test: 60.8259991	best: 60.5938104 (343)	total: 6.04s	remaining: 10.7s
# 360:	learn: 20.9608136	test: 60.8158874	best: 60.5938104 (343)	total: 6.05s	remaining: 10.7s
# 361:	learn: 20.9109951	test: 60.7882940	best: 60.5938104 (343)	total: 6.07s	remaining: 10.7s
# 362:	learn: 20.8744237	test: 60.7548241	best: 60.5938104 (343)	total: 6.1s	remaining: 10.7s
# 363:	learn: 20.8513996	test: 60.7632365	best: 60.5938104 (343)	total: 6.12s	remaining: 10.7s
# 364:	learn: 20.8213323	test: 60.5823903	best: 60.5823903 (364)	total: 6.13s	remaining: 10.7s
# 365:	learn: 20.7788911	test: 60.5921673	best: 60.5823903 (364)	total: 6.15s	remaining: 10.7s
# 366:	learn: 20.7468793	test: 60.5712174	best: 60.5712174 (366)	total: 6.17s	remaining: 10.6s
# 367:	learn: 20.6850852	test: 60.5830380	best: 60.5712174 (366)	total: 6.18s	remaining: 10.6s
# 368:	learn: 20.6373656	test: 60.5974195	best: 60.5712174 (366)	total: 6.19s	remaining: 10.6s
# 369:	learn: 20.5918763	test: 60.5354971	best: 60.5354971 (369)	total: 6.21s	remaining: 10.6s
# 370:	learn: 20.5311598	test: 60.5284275	best: 60.5284275 (370)	total: 6.24s	remaining: 10.6s
# 371:	learn: 20.4906898	test: 60.4036630	best: 60.4036630 (371)	total: 6.28s	remaining: 10.6s
# 372:	learn: 20.4450543	test: 60.3780538	best: 60.3780538 (372)	total: 6.3s	remaining: 10.6s
# 373:	learn: 20.3989708	test: 60.3873955	best: 60.3780538 (372)	total: 6.31s	remaining: 10.6s
# 374:	learn: 20.3649353	test: 60.4021669	best: 60.3780538 (372)	total: 6.33s	remaining: 10.5s
# 375:	learn: 20.3311988	test: 60.3849988	best: 60.3780538 (372)	total: 6.34s	remaining: 10.5s
# 376:	learn: 20.2916214	test: 60.3843780	best: 60.3780538 (372)	total: 6.35s	remaining: 10.5s
# 377:	learn: 20.2693588	test: 60.3798831	best: 60.3780538 (372)	total: 6.36s	remaining: 10.5s
# 378:	learn: 20.2327922	test: 60.3670586	best: 60.3670586 (378)	total: 6.37s	remaining: 10.4s
# 379:	learn: 20.2188483	test: 60.3744719	best: 60.3670586 (378)	total: 6.39s	remaining: 10.4s
# 380:	learn: 20.1859685	test: 60.2679674	best: 60.2679674 (380)	total: 6.42s	remaining: 10.4s
# 381:	learn: 20.1414073	test: 60.3455580	best: 60.2679674 (380)	total: 6.47s	remaining: 10.5s
# 382:	learn: 20.1115744	test: 60.3453175	best: 60.2679674 (380)	total: 6.48s	remaining: 10.4s
# 383:	learn: 20.0785906	test: 60.4634887	best: 60.2679674 (380)	total: 6.48s	remaining: 10.4s
# 384:	learn: 20.0492790	test: 60.4666567	best: 60.2679674 (380)	total: 6.48s	remaining: 10.4s
# 385:	learn: 20.0037653	test: 60.4397357	best: 60.2679674 (380)	total: 6.49s	remaining: 10.3s
# 386:	learn: 19.9892376	test: 60.4206798	best: 60.2679674 (380)	total: 6.49s	remaining: 10.3s
# 387:	learn: 19.9465534	test: 60.3981599	best: 60.2679674 (380)	total: 6.5s	remaining: 10.2s
# 388:	learn: 19.8960219	test: 60.4656089	best: 60.2679674 (380)	total: 6.5s	remaining: 10.2s
# 389:	learn: 19.8858207	test: 60.4854347	best: 60.2679674 (380)	total: 6.57s	remaining: 10.3s
# 390:	learn: 19.8651819	test: 60.4908671	best: 60.2679674 (380)	total: 6.59s	remaining: 10.3s
# 391:	learn: 19.8236101	test: 60.3543184	best: 60.2679674 (380)	total: 6.61s	remaining: 10.2s
# 392:	learn: 19.7940181	test: 60.4131110	best: 60.2679674 (380)	total: 6.62s	remaining: 10.2s
# 393:	learn: 19.7456910	test: 60.3668139	best: 60.2679674 (380)	total: 6.66s	remaining: 10.2s
# 394:	learn: 19.6937953	test: 60.3774854	best: 60.2679674 (380)	total: 6.7s	remaining: 10.3s
# 395:	learn: 19.6713169	test: 60.3719048	best: 60.2679674 (380)	total: 6.72s	remaining: 10.2s
# 396:	learn: 19.6425296	test: 60.3641149	best: 60.2679674 (380)	total: 6.73s	remaining: 10.2s
# 397:	learn: 19.6297889	test: 60.3479409	best: 60.2679674 (380)	total: 6.76s	remaining: 10.2s
# 398:	learn: 19.5953917	test: 60.3254777	best: 60.2679674 (380)	total: 6.79s	remaining: 10.2s
# 399:	learn: 19.5569145	test: 60.3356090	best: 60.2679674 (380)	total: 6.81s	remaining: 10.2s
# 400:	learn: 19.5181992	test: 60.3734853	best: 60.2679674 (380)	total: 6.83s	remaining: 10.2s
# 401:	learn: 19.4887688	test: 60.3821106	best: 60.2679674 (380)	total: 6.85s	remaining: 10.2s
# 402:	learn: 19.4498986	test: 60.4116162	best: 60.2679674 (380)	total: 6.86s	remaining: 10.2s
# 403:	learn: 19.4142494	test: 60.4297533	best: 60.2679674 (380)	total: 6.87s	remaining: 10.1s
# 404:	learn: 19.3585656	test: 60.4131853	best: 60.2679674 (380)	total: 6.88s	remaining: 10.1s
# 405:	learn: 19.3008511	test: 60.4138233	best: 60.2679674 (380)	total: 6.91s	remaining: 10.1s
# 406:	learn: 19.2545357	test: 60.4173949	best: 60.2679674 (380)	total: 6.94s	remaining: 10.1s
# 407:	learn: 19.2152307	test: 60.4154165	best: 60.2679674 (380)	total: 6.97s	remaining: 10.1s
# 408:	learn: 19.2036452	test: 60.4113093	best: 60.2679674 (380)	total: 7.01s	remaining: 10.1s
# 409:	learn: 19.1808495	test: 60.4073227	best: 60.2679674 (380)	total: 7.04s	remaining: 10.1s
# 410:	learn: 19.1579479	test: 60.3981074	best: 60.2679674 (380)	total: 7.07s	remaining: 10.1s
# 411:	learn: 19.1067982	test: 60.5357436	best: 60.2679674 (380)	total: 7.1s	remaining: 10.1s
# 412:	learn: 19.0810975	test: 60.5198631	best: 60.2679674 (380)	total: 7.13s	remaining: 10.1s
# 413:	learn: 19.0306736	test: 60.4942947	best: 60.2679674 (380)	total: 7.15s	remaining: 10.1s
# 414:	learn: 18.9915144	test: 60.4590447	best: 60.2679674 (380)	total: 7.17s	remaining: 10.1s
# 415:	learn: 18.9681192	test: 60.4318261	best: 60.2679674 (380)	total: 7.19s	remaining: 10.1s
# 416:	learn: 18.9406414	test: 60.4140232	best: 60.2679674 (380)	total: 7.22s	remaining: 10.1s
# 417:	learn: 18.9032172	test: 60.4379441	best: 60.2679674 (380)	total: 7.25s	remaining: 10.1s
# 418:	learn: 18.8658423	test: 60.4440497	best: 60.2679674 (380)	total: 7.28s	remaining: 10.1s
# 419:	learn: 18.8383480	test: 60.4304841	best: 60.2679674 (380)	total: 7.3s	remaining: 10.1s
# 420:	learn: 18.8259676	test: 60.4055669	best: 60.2679674 (380)	total: 7.32s	remaining: 10.1s
# 421:	learn: 18.7957265	test: 60.3895863	best: 60.2679674 (380)	total: 7.33s	remaining: 10s
# 422:	learn: 18.7620132	test: 60.3829828	best: 60.2679674 (380)	total: 7.34s	remaining: 10s
# 423:	learn: 18.7210779	test: 60.3782586	best: 60.2679674 (380)	total: 7.35s	remaining: 9.98s
# 424:	learn: 18.7007912	test: 60.3746985	best: 60.2679674 (380)	total: 7.35s	remaining: 9.94s
# 425:	learn: 18.6697919	test: 60.3056374	best: 60.2679674 (380)	total: 7.35s	remaining: 9.91s
# 426:	learn: 18.6252352	test: 60.3234507	best: 60.2679674 (380)	total: 7.36s	remaining: 9.87s
# 427:	learn: 18.5831803	test: 60.3004810	best: 60.2679674 (380)	total: 7.36s	remaining: 9.84s
# 428:	learn: 18.5405849	test: 60.4423371	best: 60.2679674 (380)	total: 7.38s	remaining: 9.82s
# 429:	learn: 18.5036511	test: 60.4277007	best: 60.2679674 (380)	total: 7.41s	remaining: 9.82s
# 430:	learn: 18.4751326	test: 60.4390659	best: 60.2679674 (380)	total: 7.44s	remaining: 9.83s
# 431:	learn: 18.4384446	test: 60.4503719	best: 60.2679674 (380)	total: 7.47s	remaining: 9.82s
# 432:	learn: 18.4082699	test: 60.4428880	best: 60.2679674 (380)	total: 7.48s	remaining: 9.8s
# 433:	learn: 18.3741247	test: 60.4688425	best: 60.2679674 (380)	total: 7.5s	remaining: 9.78s
# 434:	learn: 18.3381336	test: 60.4249115	best: 60.2679674 (380)	total: 7.51s	remaining: 9.75s
# 435:	learn: 18.3053049	test: 60.3844521	best: 60.2679674 (380)	total: 7.52s	remaining: 9.73s
# 436:	learn: 18.2786394	test: 60.3714814	best: 60.2679674 (380)	total: 7.55s	remaining: 9.72s
# 437:	learn: 18.2355626	test: 60.3409860	best: 60.2679674 (380)	total: 7.57s	remaining: 9.72s
# 438:	learn: 18.2145488	test: 60.3065538	best: 60.2679674 (380)	total: 7.59s	remaining: 9.7s
# 439:	learn: 18.1732291	test: 60.3059698	best: 60.2679674 (380)	total: 7.61s	remaining: 9.68s
# 440:	learn: 18.1377645	test: 60.2980747	best: 60.2679674 (380)	total: 7.63s	remaining: 9.67s
# 441:	learn: 18.1043394	test: 60.3048249	best: 60.2679674 (380)	total: 7.64s	remaining: 9.64s
# 442:	learn: 18.0727307	test: 60.3693125	best: 60.2679674 (380)	total: 7.65s	remaining: 9.62s
# 443:	learn: 18.0411002	test: 60.3541909	best: 60.2679674 (380)	total: 7.66s	remaining: 9.59s
# 444:	learn: 18.0316590	test: 60.3499443	best: 60.2679674 (380)	total: 7.67s	remaining: 9.56s
# 445:	learn: 17.9955032	test: 60.3458785	best: 60.2679674 (380)	total: 7.7s	remaining: 9.56s
# 446:	learn: 17.9811785	test: 60.3750505	best: 60.2679674 (380)	total: 7.75s	remaining: 9.58s
# 447:	learn: 17.9750683	test: 60.3841999	best: 60.2679674 (380)	total: 7.77s	remaining: 9.57s
# 448:	learn: 17.9382388	test: 60.3584497	best: 60.2679674 (380)	total: 7.79s	remaining: 9.55s
# 449:	learn: 17.9054207	test: 60.3283524	best: 60.2679674 (380)	total: 7.82s	remaining: 9.56s
# 450:	learn: 17.8691552	test: 60.3482242	best: 60.2679674 (380)	total: 7.86s	remaining: 9.56s
# 451:	learn: 17.8486783	test: 60.3213221	best: 60.2679674 (380)	total: 7.88s	remaining: 9.56s
# 452:	learn: 17.8149632	test: 60.3173139	best: 60.2679674 (380)	total: 7.9s	remaining: 9.54s
# 453:	learn: 17.7874241	test: 60.2992983	best: 60.2679674 (380)	total: 7.91s	remaining: 9.51s
# 454:	learn: 17.7826512	test: 60.2953934	best: 60.2679674 (380)	total: 7.92s	remaining: 9.49s
# 455:	learn: 17.7343330	test: 60.3104228	best: 60.2679674 (380)	total: 7.93s	remaining: 9.46s
# 456:	learn: 17.6917368	test: 60.3041705	best: 60.2679674 (380)	total: 7.96s	remaining: 9.46s
# 457:	learn: 17.6578369	test: 60.2854790	best: 60.2679674 (380)	total: 7.99s	remaining: 9.46s
# 458:	learn: 17.6343264	test: 60.2893576	best: 60.2679674 (380)	total: 8.02s	remaining: 9.45s
# 459:	learn: 17.6167740	test: 60.3800089	best: 60.2679674 (380)	total: 8.04s	remaining: 9.44s
# 460:	learn: 17.5854633	test: 60.3711882	best: 60.2679674 (380)	total: 8.05s	remaining: 9.42s
# 461:	learn: 17.5525202	test: 60.5321410	best: 60.2679674 (380)	total: 8.07s	remaining: 9.4s
# 462:	learn: 17.5322968	test: 60.4406495	best: 60.2679674 (380)	total: 8.08s	remaining: 9.38s
# 463:	learn: 17.5055699	test: 60.4497918	best: 60.2679674 (380)	total: 8.09s	remaining: 9.35s
# 464:	learn: 17.4450933	test: 60.4681092	best: 60.2679674 (380)	total: 8.11s	remaining: 9.33s
# 465:	learn: 17.4025311	test: 60.4560009	best: 60.2679674 (380)	total: 8.13s	remaining: 9.31s
# 466:	learn: 17.3601023	test: 60.4584355	best: 60.2679674 (380)	total: 8.16s	remaining: 9.31s
# 467:	learn: 17.3085341	test: 60.4432761	best: 60.2679674 (380)	total: 8.19s	remaining: 9.31s
# 468:	learn: 17.2730303	test: 60.4515813	best: 60.2679674 (380)	total: 8.21s	remaining: 9.3s
# 469:	learn: 17.2387351	test: 60.4460393	best: 60.2679674 (380)	total: 8.22s	remaining: 9.27s
# 470:	learn: 17.2113670	test: 60.4437757	best: 60.2679674 (380)	total: 8.23s	remaining: 9.24s
# 471:	learn: 17.1643332	test: 60.5361495	best: 60.2679674 (380)	total: 8.24s	remaining: 9.22s
# 472:	learn: 17.1352197	test: 60.5080075	best: 60.2679674 (380)	total: 8.25s	remaining: 9.19s
# 473:	learn: 17.1042766	test: 60.4965463	best: 60.2679674 (380)	total: 8.26s	remaining: 9.17s
# 474:	learn: 17.0722625	test: 60.4863253	best: 60.2679674 (380)	total: 8.29s	remaining: 9.16s
# 475:	learn: 17.0369366	test: 60.4504034	best: 60.2679674 (380)	total: 8.32s	remaining: 9.16s
# 476:	learn: 17.0068126	test: 60.4895521	best: 60.2679674 (380)	total: 8.35s	remaining: 9.16s
# 477:	learn: 16.9715287	test: 60.4487387	best: 60.2679674 (380)	total: 8.37s	remaining: 9.14s
# 478:	learn: 16.9347267	test: 60.4489874	best: 60.2679674 (380)	total: 8.39s	remaining: 9.12s
# 479:	learn: 16.9132034	test: 60.4313586	best: 60.2679674 (380)	total: 8.4s	remaining: 9.11s
# 480:	learn: 16.8753225	test: 60.4334307	best: 60.2679674 (380)	total: 8.42s	remaining: 9.08s
# 481:	learn: 16.8404416	test: 60.4362284	best: 60.2679674 (380)	total: 8.43s	remaining: 9.06s
# 482:	learn: 16.8068073	test: 60.4563484	best: 60.2679674 (380)	total: 8.43s	remaining: 9.03s
# 483:	learn: 16.7640502	test: 60.4229379	best: 60.2679674 (380)	total: 8.44s	remaining: 8.99s
# 484:	learn: 16.7458099	test: 60.4313249	best: 60.2679674 (380)	total: 8.44s	remaining: 8.96s
# 485:	learn: 16.7349655	test: 60.4278909	best: 60.2679674 (380)	total: 8.44s	remaining: 8.93s
# 486:	learn: 16.7302107	test: 60.4263747	best: 60.2679674 (380)	total: 8.45s	remaining: 8.9s
# 487:	learn: 16.7064041	test: 60.4360174	best: 60.2679674 (380)	total: 8.48s	remaining: 8.9s
# 488:	learn: 16.6786570	test: 60.4426999	best: 60.2679674 (380)	total: 8.51s	remaining: 8.89s
# 489:	learn: 16.6448727	test: 60.4365405	best: 60.2679674 (380)	total: 8.54s	remaining: 8.89s
# 490:	learn: 16.6041075	test: 60.4936458	best: 60.2679674 (380)	total: 8.55s	remaining: 8.87s
# 491:	learn: 16.5741141	test: 60.4589845	best: 60.2679674 (380)	total: 8.57s	remaining: 8.85s
# 492:	learn: 16.5326609	test: 60.4680534	best: 60.2679674 (380)	total: 8.58s	remaining: 8.82s
# 493:	learn: 16.5061622	test: 60.4780820	best: 60.2679674 (380)	total: 8.59s	remaining: 8.8s
# 494:	learn: 16.4763242	test: 60.4573462	best: 60.2679674 (380)	total: 8.62s	remaining: 8.79s
# 495:	learn: 16.4563519	test: 60.4386431	best: 60.2679674 (380)	total: 8.65s	remaining: 8.79s
# 496:	learn: 16.4271022	test: 60.4461759	best: 60.2679674 (380)	total: 8.68s	remaining: 8.78s
# 497:	learn: 16.4069555	test: 60.4361584	best: 60.2679674 (380)	total: 8.7s	remaining: 8.77s
# 498:	learn: 16.3852102	test: 60.4200960	best: 60.2679674 (380)	total: 8.71s	remaining: 8.75s
# 499:	learn: 16.3514378	test: 60.4285990	best: 60.2679674 (380)	total: 8.72s	remaining: 8.72s
# 500:	learn: 16.3250183	test: 60.4555811	best: 60.2679674 (380)	total: 8.73s	remaining: 8.7s
# 501:	learn: 16.3010451	test: 60.4332193	best: 60.2679674 (380)	total: 8.74s	remaining: 8.67s
# 502:	learn: 16.2712057	test: 60.4468576	best: 60.2679674 (380)	total: 8.77s	remaining: 8.66s
# 503:	learn: 16.2415276	test: 60.4456876	best: 60.2679674 (380)	total: 8.79s	remaining: 8.65s
# 504:	learn: 16.2017840	test: 60.4704595	best: 60.2679674 (380)	total: 8.81s	remaining: 8.63s
# 505:	learn: 16.1937944	test: 60.4745522	best: 60.2679674 (380)	total: 8.83s	remaining: 8.62s
# 506:	learn: 16.1619854	test: 60.4765361	best: 60.2679674 (380)	total: 8.84s	remaining: 8.6s
# 507:	learn: 16.1222258	test: 60.4616037	best: 60.2679674 (380)	total: 8.86s	remaining: 8.58s
# 508:	learn: 16.0838006	test: 60.4473414	best: 60.2679674 (380)	total: 8.88s	remaining: 8.56s
# 509:	learn: 16.0601653	test: 60.4422121	best: 60.2679674 (380)	total: 8.89s	remaining: 8.54s
# 510:	learn: 16.0475574	test: 60.4219386	best: 60.2679674 (380)	total: 8.9s	remaining: 8.52s
# 511:	learn: 16.0244549	test: 60.4118281	best: 60.2679674 (380)	total: 8.91s	remaining: 8.49s
# 512:	learn: 15.9846145	test: 60.4136995	best: 60.2679674 (380)	total: 8.92s	remaining: 8.46s
# 513:	learn: 15.9534603	test: 60.4200991	best: 60.2679674 (380)	total: 8.93s	remaining: 8.45s
# 514:	learn: 15.9410908	test: 60.4039174	best: 60.2679674 (380)	total: 8.96s	remaining: 8.44s
# 515:	learn: 15.9125214	test: 60.4045222	best: 60.2679674 (380)	total: 9s	remaining: 8.44s
# 516:	learn: 15.8921392	test: 60.3665048	best: 60.2679674 (380)	total: 9.02s	remaining: 8.43s
# 517:	learn: 15.8678562	test: 60.3374131	best: 60.2679674 (380)	total: 9.04s	remaining: 8.41s
# ...
# 830:	learn: 9.9943798	test: 111.3674569	best: 111.3617334 (823)	total: 27.4s	remaining: 5.56s
#
# bestTest = 111.1926509
# bestIteration = 858
#
# {'l2_leaf_reg': 5}

# %%
show_series(
    [train_y[-90:], test_y, predictionsDF[model_name]],
    labels=["train", "test", "predict"],
)

# %%
print(grid_search_results["params"])
# Out:
# {'l2_leaf_reg': 5}

# %%
del (
    train_x,
    train_y,
    test_x,
    test_y,
    train_pool,
    test_pool,
)

# %% [markdown]
# ### Data Prep For LSTM

# %%
import tensorflow as tf


model, yhat, model_name = None, None, None

model_name = "LSTM_Dense"

WINDOW_LEN = 24
BATCH_SIZE = 64
BUFFER_SIZE = 100
EPOCHS_ = 15


def window_data(X_data, y_data, window_len=7):
    x_, y_ = [], []
    for i in range(window_len - 1, len(X_data)):
        x_.append(X_data[i - window_len + 1 : i + 1])
        y_.append(y_data[i])
    return np.array(x_), np.array(y_)


print(f"dataframe shape {dataframe.shape}")

build_features = lambda df: (
    df.pipe(create_lag_feature, column=TARGET_COLUMN, lags=LAGS)
    .pipe(create_window_feature, column=TARGET_COLUMN, window_len=FEATURE_WINDOW_LEN)
    .pipe(create_datetime_feature, features_name=DT_FEATURES)
    .pipe(create_cyclic_feature, features_name=CYCLIC_FEATURE)
    .pipe(drop_null_rows)
)

df_feat = build_features(dataframe)

print(f"dataframe shape after Feature Union {df_feat.shape}", end="\n\n")

data_x, data_y = seperate_target(df_feat, TARGET_COLUMN)

print(f"data_x shape after seperate_target {data_x.shape}")
print(f"data_y shape after seperate_target {data_y.shape}", end="\n\n")

scaler_x = StandardScaler()
scaler_x.fit(data_x)
data_x_np = scaler_x.transform(data_x)

scaler_y = StandardScaler()
scaler_y.fit(data_y)
data_y_np = scaler_y.transform(data_y)

print(f"data_x shape after StandardScaler {data_x_np.shape}")
print(f"data_y shape after StandardScaler {data_y_np.shape}", end="\n\n")

x_window, y_window = window_data(data_x_np, data_y_np, window_len=WINDOW_LEN)

print(f"x_window shape after Windowing {x_window.shape}")
print(f"y_window shape after Windowing {y_window.shape}", end="\n\n")

x_train_data, x_test_data = x_window[:-TEST_SIZE], x_window[-TEST_SIZE:]
y_train_data, y_test_data = y_window[:-TEST_SIZE], y_window[-TEST_SIZE:]

print(f"x_train_data shape after Test Train Split {x_train_data.shape}")
print(f"x_test_data  shape after Test Train Split {x_test_data.shape}")
print(f"y_train_data shape after Test Train Split {y_train_data.shape}")
print(f"y_test_data  shape after Test Train Split {y_test_data.shape}", end="\n\n")

train_data = (
    tf.data.Dataset.from_tensor_slices((x_train_data, y_train_data))
    .cache()
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
)


test_data = (
    tf.data.Dataset.from_tensor_slices((x_test_data, y_test_data))
    .batch(BATCH_SIZE)
    .repeat()
)
# Out:
# dataframe shape (1560, 13)
# dataframe shape after Feature Union (1557, 32)
#
# data_x shape after seperate_target (1557, 31)
# data_y shape after seperate_target (1557, 1)
#
# data_x shape after StandardScaler (1557, 31)
# data_y shape after StandardScaler (1557, 1)
#
# x_window shape after Windowing (1534, 24, 31)
# y_window shape after Windowing (1534, 1)
#
# x_train_data shape after Test Train Split (1504, 24, 31)
# x_test_data  shape after Test Train Split (30, 24, 31)
# y_train_data shape after Test Train Split (1504, 1)
# y_test_data  shape after Test Train Split (30, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = tf.keras.models.Sequential(
    [
        LSTM(64, input_shape=x_window.shape[-2:], dropout=0.0, activation="relu"),
        Dense(64, activation="relu"),
        Dense(64, activation="relu"),
        Dense(1),
    ]
)

model.compile(optimizer="adam", loss="mse", metrics="mae")

training_history = model.fit(
    train_data,
    epochs=25,
    steps_per_epoch=200,
    validation_data=test_data,
    validation_steps=50,
)
yhat = model.predict(x_test_data)
print(yhat.shape)
# Out:
# Epoch 1/25
# 200/200 [==============================] - 7s 23ms/step - loss: 0.2295 - mae: 0.3260 - val_loss: 0.1390 - val_mae: 0.3198
# Epoch 2/25
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0667 - mae: 0.2015 - val_loss: 0.0145 - val_mae: 0.0949
# Epoch 3/25
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0191 - mae: 0.1081 - val_loss: 0.0090 - val_mae: 0.0786
# Epoch 4/25
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0326 - mae: 0.1390 - val_loss: 0.0103 - val_mae: 0.0764
# Epoch 5/25
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0158 - mae: 0.0962 - val_loss: 0.0105 - val_mae: 0.0845
# Epoch 6/25
# 200/200 [==============================] - 6s 29ms/step - loss: 0.0197 - mae: 0.1082 - val_loss: 0.0086 - val_mae: 0.0767
# Epoch 7/25
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0181 - mae: 0.1047 - val_loss: 0.0163 - val_mae: 0.1047
# Epoch 8/25
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0180 - mae: 0.1018 - val_loss: 0.0082 - val_mae: 0.0715
# Epoch 9/25
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0179 - mae: 0.0995 - val_loss: 0.0110 - val_mae: 0.0865
# Epoch 10/25
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0172 - mae: 0.0997 - val_loss: 0.0087 - val_mae: 0.0717
# Epoch 11/25
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0148 - mae: 0.0937 - val_loss: 0.0168 - val_mae: 0.1108
# Epoch 12/25
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0190 - mae: 0.0991 - val_loss: 0.0154 - val_mae: 0.1015
# Epoch 13/25
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0163 - mae: 0.0973 - val_loss: 0.0088 - val_mae: 0.0773
# Epoch 14/25
# 200/200 [==============================] - 5s 27ms/step - loss: 0.0103 - mae: 0.0786 - val_loss: 0.0110 - val_mae: 0.0813
# Epoch 15/25
# 200/200 [==============================] - 5s 25ms/step - loss: 0.0123 - mae: 0.0854 - val_loss: 0.0106 - val_mae: 0.0846
# Epoch 16/25
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0162 - mae: 0.0945 - val_loss: 0.0157 - val_mae: 0.0999
# Epoch 17/25
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0155 - mae: 0.0876 - val_loss: 0.0110 - val_mae: 0.0866
# Epoch 18/25
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0130 - mae: 0.0845 - val_loss: 0.0088 - val_mae: 0.0746
# Epoch 19/25
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0130 - mae: 0.0861 - val_loss: 0.0260 - val_mae: 0.1421
# Epoch 20/25
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0090 - mae: 0.0728 - val_loss: 0.0306 - val_mae: 0.1567
# Epoch 21/25
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0104 - mae: 0.0755 - val_loss: 0.0258 - val_mae: 0.1421
# Epoch 22/25
# 200/200 [==============================] - 5s 24ms/step - loss: 0.0104 - mae: 0.0761 - val_loss: 0.0383 - val_mae: 0.1784
# Epoch 23/25
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0121 - mae: 0.0788 - val_loss: 0.0527 - val_mae: 0.2153
# Epoch 24/25
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0158 - mae: 0.0896 - val_loss: 0.0296 - val_mae: 0.1477
# Epoch 25/25
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0074 - mae: 0.0663 - val_loss: 0.0109 - val_mae: 0.0844
# 1/1 [==============================] - 0s 358ms/step
# (30, 1)

# %%
yhat_scaled = scaler_y.inverse_transform(yhat)
y_test_data_scaled = scaler_y.inverse_transform(y_test_data)
y_train_data_scaled = scaler_y.inverse_transform(y_train_data)


print(f"yhat_scaled shape {yhat_scaled.shape} {y_test_data_scaled.shape}")
resultsDict[model_name] = evaluate(y_test_data_scaled, yhat_scaled)
# Out:
# yhat_scaled shape (30, 1) (30, 1)

# %%
plot_tf_training_history(training_history)

# %%
y_hat_df = pd.DataFrame(
    yhat_scaled, index=data_y.index[-TEST_SIZE:], columns=["TARGET_COLUMN"]
)

y_test_data_df = pd.DataFrame(
    y_test_data_scaled, index=data_y.index[-TEST_SIZE:], columns=["TARGET_COLUMN"]
)

y_train_data_df = pd.DataFrame(
    y_train_data_scaled,
    index=data_y.index[WINDOW_LEN - 1 : -TEST_SIZE],
    columns=["TARGET_COLUMN"],
)

show_series(
    [y_train_data_df[-90:], y_test_data_df, y_hat_df],
    labels=["train", "test", "predict"],
)

# %%
resultsDF = pd.DataFrame.from_dict(resultsDict)
resultsDF.head()
# Out:
#       KNeighborsRegressor  BayesianRidge    LassoCV  RandomForestRegressor  \
# mae             84.282222      34.531201  46.725282              30.877724
# rmse            99.107293      41.079853  54.789204              36.605701
# mape             0.084744       0.033769   0.047202               0.030088
# r2               0.455497       0.906449   0.833590               0.925717
#
#       XGBRegressor  LGBMRegressor  CatBoostRegressor  LSTM_Dense
# mae      28.987366      40.930818          37.580054   25.671927
# rmse     35.122370      49.502985          46.549659   31.771799
# mape      0.028497       0.039494           0.035959    0.025183
# r2        0.931616       0.864152           0.879878    0.944041

# %%
resultsDF.T
# Out:
#                              mae       rmse      mape        r2
# KNeighborsRegressor    84.282222  99.107293  0.084744  0.455497
# BayesianRidge          34.531201  41.079853  0.033769  0.906449
# LassoCV                46.725282  54.789204  0.047202  0.833590
# RandomForestRegressor  30.877724  36.605701  0.030088  0.925717
# XGBRegressor           28.987366  35.122370  0.028497  0.931616
# LGBMRegressor          40.930818  49.502985  0.039494  0.864152
# CatBoostRegressor      37.580054  46.549659  0.035959  0.879878
# LSTM_Dense             25.671927  31.771799  0.025183  0.944041

# %%
plot_metrics(resultsDF)

# %%
resultsDF_T = resultsDF.T.copy(deep=True)
resultsDF_T["Dataset"] = "Air_Quality"
resultsDF_T["Mode"] = "Singel_step"

result_path = "./results/results.csv"

if os.path.isfile(result_path) is False:
    resultsDF_T.to_csv(result_path, index=False)
else:
    result_data = pd.read_csv(result_path)
    new_data = pd.concat([result_data, resultsDF_T])
    new_data.to_csv(result_path, index=False)
